# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 737.7 kB/s eta 0:00:000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.7/871.7 kB 20.7 MB/s eta 0:00:0000:01
# ...

# %%
data_dir='car-images/shreyas_car_images'

# %%
import os 
from ultralytics import YOLO
model = YOLO("yolov8n-cls.pt") 

results=model.train(data=data_dir,imgsz=512,epochs=20)
# Out:
# ...
# 100%|██████████| 5.31M/5.31M [00:00<00:00, 104MB/s]
# Ultralytics YOLOv8.2.89 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...
